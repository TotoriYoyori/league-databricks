-- %%
USE CATALOG league_records;

USE SCHEMA gold;

WITH matches_sample AS (
    SELECT match_id
    FROM matchend_pivot_teamstats
    ORDER BY RANDOM()
    LIMIT 300
)

SELECT *
FROM item_recommendations
ORDER BY RANDOM()
LIMIT 150
;
